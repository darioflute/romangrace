# %% [markdown]
# # Notes

# %% [markdown]
# ```
# conda create --name romangrace python=3.13 -y
# conda activate romangrace
# pip install roman_datamodels
# conda install jupyterlab -y
# conda install matplotlib -y
# pip install PyQt6
# pip install maskfill
# ```
